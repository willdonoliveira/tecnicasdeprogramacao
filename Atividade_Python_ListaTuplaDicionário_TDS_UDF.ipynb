# %% [markdown]
# <a href="https://colab.research.google.com/github/willdonoliveira/tecnicasdeprogramacao/blob/main/Atividade_Python_ListaTuplaDicion%C3%A1rio_TDS_UDF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Aplicações com listas, tuplas e dicionários

# %%
alunos_db = {
    ("matricula": "35489658"; "nome": "Ana Silva"; "curso": "Sistemas de Informação"),
     ("matricula": "35489784"; "nome": "Pedro Santos"; "curso": "Arquitetura"),
     ("matricula": "35488721"; "nome": "João Lima"; "curso": "Turismo"),
}

print("1. Sistema Simplificado de Cadastro de alunos")
print("-" * 40)

#1. Adicionar Novo Aluno(CREATE)
print("-> Adicionando novo aluno...")
novo_aluno = ("matricula": "47859625"; "nome": "Jonas Lima"; "curso": "Engenharia Civil"),
alunos_db.append(novo_aluno)
print("Aluno adicionado com sucesso!")

#2. Buscar aluno por matrícula(CREATE)
matrícula = "47859625"
aluno_encontrado = next((aluno for aluno in alunos_db if aluno["matricula"] == matrícula_busca), None)
if aluno_encontrado:
    print(f"\nAluno encontrado: [matricula_busca]):")

    print(f"Nome: {aluno_encontrado["nome"]}")
    print(f"Curso: {aluno_encontrado["curso"]}")

    else:
        print(f"\nAluno com matrícula {matrícula_busca} não encontrado.")

#3. Atualizar Informações com o Curso (CREATE)
matricula_update = "47859625"
for aluno in alunos_db:
  if aluno["matricula"] == matricula_update:
    aluno["curso"] = "Engenharia Civil"
    print(f"\nCurso do Aluno {aluno["nome"]} atualizado para: {aluno["curso"]}")
    break
else:
    print("-" * 40)
