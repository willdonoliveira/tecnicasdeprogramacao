# %% [markdown]
# <a href="https://colab.research.google.com/github/willdonoliveira/tecnicasdeprogramacao/blob/main/Eng_Sof_6nov_Willdon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Operadores

# %%
2**3
# Out:
# 8

# %%
23/7
# Out:
# 3.2857142857142856

# %%
23%7
# Out:
# 2

# %%
5+5/5*5
# Out:
# 10.0

# %%
#Faça um programa que leia dois números inteiros e exiba a soma deles.
n1 = int(input("Digite um valor: "))
n2 = int(input("Digite um valor: "))
soma = n1+n2
print(f"A soma dos valores é {soma}")
# Out:
# Digite um valor: 5
# Digite um valor: 6
# A soma dos valores é 11

# %%
#Faça um programa que leia a nota que um aluno tirou em P1(Prova 1) e P2(Prova 2). Calcule a média aritmética. Exiba esse resultado na tela.
p1 = float(input("Digite a primaira nota: "))
p2 = float(input("Digite a primaira nota: "))
media = (p1+p2)/2
print(f"A média é {media}")
# Out:
#   File "/tmp/ipython-input-547226144.py", line 5
#     print("A média é" . (p1+p2/2))
#                         ^
# SyntaxError: invalid syntax

# %%
#Leia um nome armazenado em uma variável e imprima: Olá, nome_pessoa!
(nome_pessoa é a variável)
nome_pessoal = str(input("Digite seu nome"))
print (f"O seu nome é {nome_pessoal}")

# %%
#Solicite que o usuário digite seu nome. Solicite que o usuários digite seu ano de nascimento (formato AAAA).Exiba na tela: nome_usuario nasceu em ano_nascimento!(nome_usuario e ano_nascimento são as variáveis
nome_pessoal = str(input("Digite seu nome"))
ano_nascimento = int(input("Digite seu ano de nascimento: "))
print(f"{nome_pessoal} nasceu em {ano_nascimento}")

# %%
#Solicite que o usuário digite seu nome e sua idade. Imprima “Olá, nome! Você tem idade anos?” Imprima o ano de nascimento da pessoa (ignore meses e dias)Imprima o nome da pessoa idade vezes (João tem 18, imprime JoãoJoão...)

nome = str(input("Digite seu nome: "))
ano_nas = int(input("Digite seu ano de nascimento:"))
mult = nome * ano_nas
print(f"{nome} tem {ano_nas}, {mult}")
# Out:
# Digite seu nome: will
# Digite seu ano de nascimento:23
# will tem 23, willwillwillwillwillwillwillwillwillwillwillwillwillwillwillwillwillwillwillwillwillwillwill

# %%
#Solicite ao usuário que digite três notas depois calcule e exiba a média ponderada.
n1 = float(input("Digite a primeira nota:"))
n2 = float(input("Digite a segunda nota:"))
n3 = float(input("Digite a terceira nota:"))
media = (n1+n2+n3)/3
print(f"A média é {media}")
# Out:
# Digite a primeira nota:8
# Digite a segunda nota:5
# Digite a terceira nota:3
# A média é 5.333333333333333

# %%
#Peça ao usuário um número e exiba a soma de seus dígitos.
num = int(input("Digite um número: "))

# %%
#Peça ao usuário uma palavra e exiba-a invertida sem usar laços.
palavra = input("Digite uma palavra: ")
palavra_invertida = palavra[::-1]
print(f"A palavra invertida é {palavra_invertida}")
# Out:
# Digite uma palavra: will
# A palavra invertida é lliw
